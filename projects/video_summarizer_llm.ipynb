# %% [markdown]
# # Yutube Video Summarizer

# %%
# pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
def get_video_id(url_link):
    return url_link.split("watch?v=")[-1]

video_id = get_video_id("https://www.youtube.com/watch?v=xDQL3vWwcp0")

# %%
transcript = YouTubeTranscriptApi().fetch(video_id,['en'])

# %%
transcript
# Out:
# FetchedTranscript(snippets=[FetchedTranscriptSnippet(text="hello everyone I am Santi and I'm", start=0.16, duration=3.559), FetchedTranscriptSnippet(text='currently working as an ml engineer', start=1.839, duration=3.48), FetchedTranscriptSnippet(text='today we are going to do an awesome', start=3.719, duration=3.241), FetchedTranscriptSnippet(text='machine learning project that you can', start=5.319, duration=4.44), FetchedTranscriptSnippet(text='add to your resume and impress all the', start=6.96, duration=4.92), FetchedTranscriptSnippet(text="interviewers um I'm dedicated to", start=9.759, duration=4.201), FetchedTranscriptSnippet(text='teaching machine learning to all of you', start=11.88, duration=4.36), FetchedTranscriptSnippet(text='and to ensure that you all learned an ml', start=13.96, duration=5.319), FetchedTranscriptSnippet(text='job as soon as possible okay so without', start=16.24, duration=5.32), FetchedTranscriptSnippet(text="any further Ado let's Dive Right", start=19.279, duration=6.641), FetchedTranscriptSnippet(text='In so our title is going to be um so our', start=21.56, duration=6.479), FetchedTranscriptSnippet(text='project title is going to be uh YouTube', start=25.92, duration=4.88), FetchedTranscriptSnippet(text='video summarizer with llm', start=28.039, duration=4.641), FetchedTranscriptSnippet(text="well so what's going to do is going to", start=30.8, duration=4.04), FetchedTranscriptSnippet(text='take in a video and you can ask any', start=32.68, duration=4.0), FetchedTranscriptSnippet(text='question regarding the videos contents', start=34.84, duration=4.64), FetchedTranscriptSnippet(text="the images Etc and that's going to be", start=36.68, duration=5.199), FetchedTranscriptSnippet(text='really really good really useful as well', start=39.48, duration=4.12), FetchedTranscriptSnippet(text='and that can be a mini deployed project', start=41.879, duration=5.561), FetchedTranscriptSnippet(text='as well okay so first things first um', start=43.6, duration=5.92), FetchedTranscriptSnippet(text="let's let's let's think about why do we", start=47.44, duration=3.36), FetchedTranscriptSnippet(text='need this in the first place the', start=49.52, duration=3.0), FetchedTranscriptSnippet(text='interviewer might say why not just use', start=50.8, duration=4.64), FetchedTranscriptSnippet(text='chat GPT right because chat gpg has now', start=52.52, duration=4.76), FetchedTranscriptSnippet(text='enabled the search web feature for every', start=55.44, duration=3.799), FetchedTranscriptSnippet(text='free user right so you might be', start=57.28, duration=4.32), FetchedTranscriptSnippet(text='wondering why not just use that okay so', start=59.239, duration=3.921), FetchedTranscriptSnippet(text="let's see why we are not going to use", start=61.6, duration=3.72), FetchedTranscriptSnippet(text='that as you can see right here we have', start=63.16, duration=6.12), FetchedTranscriptSnippet(text="our chat GPT open and let's see um which", start=65.32, duration=6.439), FetchedTranscriptSnippet(text='video are we going to use yeah so this', start=69.28, duration=4.12), FetchedTranscriptSnippet(text='is a video that we are going to use', start=71.759, duration=3.761), FetchedTranscriptSnippet(text='right here as you can see my binary', start=73.4, duration=4.2), FetchedTranscriptSnippet(text='classification video which is of the', start=75.52, duration=6.08), FetchedTranscriptSnippet(text="length of 32 32 minutes okay so let's", start=77.6, duration=6.36), FetchedTranscriptSnippet(text='put this inside the chat GPD and I will', start=81.6, duration=6.28), FetchedTranscriptSnippet(text='the search web feature and say write', start=83.96, duration=7.96), FetchedTranscriptSnippet(text='the transcript for this', start=87.88, duration=4.04), FetchedTranscriptSnippet(text='this for this video because first of all', start=94.92, duration=5.0), FetchedTranscriptSnippet(text="we'll need the transcript", start=97.88, duration=4.559), F ...

# %%
transcript_text = ""
for snippet in transcript:
    transcript_text += snippet.text

# %%
# pip install wtpsplit

# %%
# pip install google-genai python-dotenv

# %%
# import os
# from dotenv import load_dotenv
# from google import genai

# load_dotenv()

# client = genai.Client(
#     api_key=os.getenv("GOOGLE_API_KEY")
# )

# response = client.models.generate_content(
#     model="gemini-2.5-pro",
#     contents="Explain linear regression in simple terms."
# )

# print(response.text)

# %%
pip install openrouter
# Out:
# Collecting openrouter
#   Downloading openrouter-0.10.0-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: httpcore>=1.0.9 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from openrouter) (1.0.9)
# Requirement already satisfied: httpx>=0.28.1 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from openrouter) (0.28.1)
# Collecting jsonpath-python>=1.0.6 (from openrouter)
#   Downloading jsonpath_python-1.1.6-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: pydantic>=2.11.2 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from openrouter) (2.13.4)
# Requirement already satisfied: certifi in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from httpcore>=1.0.9->openrouter) (2026.5.20)
# Requirement already satisfied: h11>=0.16 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from httpcore>=1.0.9->openrouter) (0.16.0)
# Requirement already satisfied: anyio in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from httpx>=0.28.1->openrouter) (4.12.1)
# Requirement already satisfied: idna in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from httpx>=0.28.1->openrouter) (3.18)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from pydantic>=2.11.2->openrouter) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from pydantic>=2.11.2->openrouter) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from pydantic>=2.11.2->openrouter) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/durvankur/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages (from pydantic>=2.11.2->openrouter) (0.4.2)
# Downloading openrouter-0.10.0-py3-none-any.whl (704 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 704.7/704.7 kB 5.9 MB/s  0:00:00
# Downloading jsonpath_python-1.1.6-py3-none-any.whl (14 kB)
# Installing collected packages: jsonpath-python, openrouter
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openrouter]2 [openrouter]
# Successfully installed jsonpath-python-1.1.6 openrouter-0.10.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from openrouter import OpenRouter
import os

with OpenRouter(api_key=os.getenv("OPENROUTER_API_KEY")) as client:
    response = client.chat.send(
        model="~openai/gpt-latest",
        messages=[
            {"role": "user", "content": "What is the meaning of life?"}
        ],
    )

    print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# UnauthorizedResponseError                 Traceback (most recent call last)
# Cell In[19], line 5
#       1 from openrouter import OpenRouter
#       2 import os
#       3
#       4 with OpenRouter(api_key=os.getenv("OPENROUTER_API_KEY")) as client:
# ----> 5     response = client.chat.send(
#       6         model="~openai/gpt-latest",
#       7         messages=[
#       8             {"role": "user", "content": "What is the meaning of life?"}
#
# File ~/Documents/Work/AI_ML/environments/default/lib/python3.12/site-packages/openrouter/chat.py:667, in Chat.send(self, messages, http_referer, x_open_router_title, x_open_router_categories, x_open_router_metadata, cache_control, debug, frequency_penalty, image_config, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, min_p, modalities, model, models, parallel_tool_calls, plugins, presence_penalty, provider, reasoning, reasoning_effort, repetition_penalty, response_format, seed, service_tier, session_id, stop, stop_server_tools_when, stream, stream_options, temperature, tool_choice, tools, top_a, top_k, top_logprobs, top_p, trace, user, retries, server_url, timeout_ms, http_headers)
#     663     http_res_text = utils.stream_to_text(http_res)
#     664     response_data = unmarshal_json_response(
#     665         errors.UnauthorizedResponseErrorData, http_res, http_res_text
#     666     )
# --> 667     raise errors.UnauthorizedResponseError(
#     668         response_data, http_res, http_res_text
#     669     )
#     670 if utils.match_response(http_res, "402", "application/json"):
#     671     http_res_text = utils.stream_to_text(http_res)
#
# UnauthorizedResponseError: No cookie auth credentials found
